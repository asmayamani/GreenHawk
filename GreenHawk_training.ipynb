# %% [markdown]
# #Training
# In this file we displaay the traaining process of the model per iteration. Note that this strictly has to be done after generating the iterataion data through the GreenHawk_active_learning_workflow.ipynb file. It also requires the connection to a GPU.

# %%
# !nvidia-smi
# Out:
# Fri Jan 20 08:46:43 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   66C    P0    28W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# /content

# %%
# !pip install ultralytics

from IPython import display
display.clear_output()
# !yolo mode=checks

# %%
from ultralytics import YOLO

from IPython.display import display, Image

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount= True)
# Out:
# Mounted at /content/drive

# %%
#Set the number of iterations (0 for initiaal round)
it = 14

# %%
import yaml
config = {
        #  'path': '../datasets/Smartathon',
         'train': '/content/drive/MyDrive/Smartathon/WRP/Iteration_'+str(it)+'/iteration'+str(it)+'SumAvgWRP_6000/images/',
         'val': '/content/drive/MyDrive/Smartathon/ValF/images/',
         'nc': 11,
         'names': ['graffiti','faded_signage','potholes','garbage',
                   'construction_road','broken_signage',
                   'bad_streetlight','bad_billboard','sand_on_road','clutter_sidewalk','unkept_facade']}

with open("data.yaml", "w") as file:
    yaml.dump(config, file, default_flow_style=False)

# %%
import glob
len(glob.glob('/content/drive/MyDrive/Smartathon/WRP/Iteration_'+str(it)+'/iteration'+str(it)+'SumAvgWRP_6000/images/*.jpg'))
# Out:
# 3660

# %%
# %cd {HOME}

# !yolo task=detect mode=train model=yolov8m.pt data=data.yaml epochs=100 imgsz=640 cache=True augment=True
# Out:
# /content
# ...
# 100% 49.7M/49.7M [00:01<00:00, 29.6MB/s]
#
# Ultralytics YOLOv8.0.11 🚀 Python-3.8.10 torch-1.13.1+cu116 CUDA:0 (Tesla T4, 15110MiB)
# ...

# %%
#Exporting the weights and the model metrics
# !zip -r /content/drive/MyDrive/Smartathon/WRP/Iteration_14/Iteration14_m_Full.zip /content/runs/detect/train
# !zip -r /content/drive/MyDrive/Smartathon/WRP/Iteration_14/Iteration14_m_W.zip /content/runs/detect/train/weights/best.pt

# %%
from google.colab import runtime
runtime.unassign()
